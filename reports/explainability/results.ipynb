# %%
import pandas as pd

file = 'results.xlsx'
df = pd.read_excel(file)

columns_to_remove = [col for col in df.columns if col.startswith('Komentarz')] + ['Zachęcamy do pozostawienia komentarza odnośnie struktury oraz zrozumienia ankiety. Pomoże nam on we wprowadzeniu potrzebnych poprawek.']
df = df.drop(columns=columns_to_remove)
df.dropna(inplace=True)

# %%
df['IT_ED'] = df['IT education'].apply(lambda x: 1 if x in ['Tak', 'Częściowo'] else 0)
df['IT_WORK'] = df['IT work'].apply(lambda x: 1 if x in ['Tak', 'Częściowo'] else 0)

# %%
df
# Out:
#          Sygnatura czasowa     Gender     Wiek  \
# 0  2025-05-25 21:06:57.445  Mężczyzna  18 - 29
# 1  2025-05-25 22:18:06.216  Mężczyzna  18 - 29
# 2  2025-05-25 22:23:38.850  Mężczyzna  18 - 29
# 3  2025-05-26 00:00:03.076  Mężczyzna  18 - 29
# 4  2025-05-26 11:08:24.465  Mężczyzna  18 - 29
# 5  2025-05-29 17:30:16.865    Kobieta  18 - 29
# 6  2025-06-01 15:32:01.276    Kobieta  18 - 29
# 7  2025-06-01 15:45:48.333  Mężczyzna  18 - 29
# 8  2025-06-01 15:56:47.025  Mężczyzna  18 - 29
# 9  2025-06-01 15:57:47.052    Kobieta  18 - 29
# 10 2025-06-01 16:02:30.206    Kobieta  18 - 29
# 11 2025-06-01 16:06:11.246    Kobieta  18 - 29
# 12 2025-06-01 16:08:50.587    Kobieta  18 - 29
# 13 2025-06-01 16:10:42.371  Mężczyzna  18 - 29
# 14 2025-06-01 16:19:56.591    Kobieta  18 - 29
# 15 2025-06-01 17:38:11.123  Mężczyzna  18 - 29
# 16 2025-06-01 18:41:02.121  Mężczyzna  18 - 29
# 17 2025-06-02 14:32:24.999  Mężczyzna  18 - 29
# 18 2025-06-02 16:19:47.023    Kobieta  18 - 29
# 19 2025-06-03 11:30:12.592    Kobieta  18 - 29
# 20 2025-06-03 11:35:07.940    Kobieta  18 - 29
# 21 2025-06-05 13:06:11.052    Kobieta  18 - 29
#
#                                           Education IT education    IT work  \
# 0                      Wyższe - licencjat, magister          Nie        Nie
# 1                        Średnie zawodowe - technik          Tak        Tak
# 2   Wyższe techniczne - inżynier, magister inżynier          Tak        Tak
# 3   Wyższe techniczne - inżynier, magister inżynier          Tak        Tak
# 4   Wyższe techniczne - inżynier, magister inżynier          Tak        Tak
# 5                          Średnie ogólnokształcące          Nie        Nie
# 6                          Średnie ogólnokształcące          Nie        Nie
# 7                          Średnie ogólnokształcące          Nie        Nie
# 8                          Średnie ogólnokształcące          Nie  Częściowo
# 9   Wyższe techniczne - inżynier, magister inżynier          Tak        Tak
# 10                     Wyższe - licencjat, magister          Tak        Tak
# 11                         Średnie ogólnokształcące          Nie        Nie
# 12                     Wyższe - licencjat, magister          Tak        Tak
# 13  Wyższe techniczne - inżynier, magister inżynier          Tak        Tak
# 14                     Wyższe - licencjat, magister          Nie        Nie
# 15  Wyższe techniczne - inżynier, magister inżynier          Tak        Tak
# 16                     Wyższe - licencjat, magister          Tak        Tak
# 17  Wyższe techniczne - inżynier, magister inżynier          Tak        Tak
# 18  Wyższe techniczne - inżynier, magister inżynier          Tak        Tak
# 19  Wyższe techniczne - inżynier, magister inżynier          Tak        Tak
# 20  Wyższe techniczne - inżynier, magister inżynier          Tak  Częściowo
# 21  Wyższe techniczne - inżynier, magister inżynier          Tak        Tak
#
#     Content-based Filtering: Filmy - Satysfakcja  \
# 0                                            3.0
# 1                                            3.0
# 2                                            4.0
# 3                                            4.0
# 4                                            5.0
# 5                                            3.0
# 6                                            5.0
# 7                                            4.0
# 8                                            2.0
# 9                                            4.0
# 10                                           1.0
# 11                                           4.0
# 12                                           4.0
# 13                                           2.0
# 14                                           1.0
# 15                                           4.0
# 16                                           3.0
# 17                                           5.0
# 18                                           3.0
# 19                                           5.0
# 20                                           5.0
# 21                                           5.0
#
#     Content-based Filtering: Filmy - Proste  \
# 0                                       3.0
# 1                                       4.0
# 2                                       5.0
# 3                                       2.0
# 4                                       5.0
# 5                                       4.0
# 6                                       5.0
# 7                                       5.0
# 8                                       3.0
# 9                                       5.0
# 10                                      1.0
# 11                                      5.0
# 12                                      5.0
# 13                                      5.0
# 14                                      1.0
# 15                                      5.0
# 16                                      5.0
# 17                                      5.0
# 18                                      4.0
# 19                                      5.0
# 20                                      4.0
# 21                                      5.0
#
#     Content-based Filtering: Filmy - Elastyczne  \
# 0                                           4.0
# 1                                           4.0
# 2                                           5.0
# 3                                           3.0
# 4                                           5.0
# 5                                           5.0
# 6                                           4.0
# 7                                           4.0
# 8                                           3.0
# 9                                           3.0
# 10                                          1.0
# 11                                          5.0
# 12                                          5.0
# 13                                          2.0
# 14                                          1.0
# 15                                          5.0
# 16                                          2.0
# 17                                          5.0
# 18                                          5.0
# 19                                          3.0
# 20                                          5.0
# 21                                          5.0
#
#     Content-based Filtering: Filmy - Ugruntowane  ...  \
# 0                                            5.0  ...
# 1                                            5.0  ...
# 2                                            5.0  ...
# 3                                            1.0  ...
# 4                                            2.0  ...
# 5                                            2.0  ...
# 6                                            5.0  ...
# 7                                            4.0  ...
# 8                                            2.0  ...
# 9                                            3.0  ...
# 10                                           1.0  ...
# 11                                           5.0  ...
# 12                                           4.0  ...
# 13                                           5.0  ...
# 14                                           1.0  ...
# 15                                           4.0  ...
# 16                                           2.0  ...
# 17                                           5.0  ...
# 18                                           4.0  ...
# 19                                           4.0  ...
# 20                                           3.0  ...
# 21                                           5.0  ...
#
#     Collaborative Filtering BPR: Posty - Rozszerzalne  \
# 0                                                 3.0
# 1                                                 4.0
# 2                                                 5.0
# 3                                                 4.0
# 4                                                 1.0
# 5                                                 3.0
# 6                                                 3.0
# 7                                                 3.0
# 8                                                 5.0
# 9                                                 4.0
# 10                                                2.0
# 11                                                5.0
# 12                                                5.0
# 13                                                4.0
# 14                                                4.0
# 15                                                2.0
# 16                                                5.0
# 17                                                5.0
# 18                                                3.0
# 19                                                5.0
# 20                                                4.0
# 21                                                4.0
#
#     Collaborative Filtering BPR: Posty - Oparte na źródłach  \
# 0                                                 4.0
# 1                                                 4.0
# 2                                                 4.0
# 3                                                 4.0
# 4                                                 1.0
# 5                                                 3.0
# 6                                                 3.0
# 7                                                 5.0
# 8                                                 3.0
# 9                                                 3.0
# 10                                                2.0
# 11                                                5.0
# 12                                                5.0
# 13                                                4.0
# 14                                                4.0
# 15                                                2.0
# 16                                                1.0
# 17                                                2.0
# 18                                                4.0
# 19                                                5.0
# 20                                                5.0
# 21                                                4.0
#
#     Reinforcement Learning: Posty - Satysfakcja  \
# 0                                           3.0
# 1                                           4.0
# 2                                           5.0
# 3                                           2.0
# 4                                           4.0
# 5                                           4.0
# 6                                           4.0
# 7                                           2.0
# 8                                           2.0
# 9                                           4.0
# 10                                          2.0
# 11                                          5.0
# 12                                          3.0
# 13                                          1.0
# 14                                          4.0
# 15                                          3.0
# 16                                          5.0
# 17                                          5.0
# 18                                          2.0
# 19                                          5.0
# 20                                          4.0
# 21                                          4.0
#
#     Reinforcement Learning: Posty - Proste  \
# 0                                      3.0
# 1                                      3.0
# 2                                      5.0
# 3                                      2.0
# 4                                      4.0
# 5                                      5.0
# 6                                      3.0
# 7                                      3.0
# 8                                      3.0
# 9                                      4.0
# 10                                     1.0
# 11                                     5.0
# 12                                     4.0
# 13                                     3.0
# 14                                     4.0
# 15                                     2.0
# 16                                     5.0
# 17                                     5.0
# 18                                     2.0
# 19                                     5.0
# 20                                     3.0
# 21                                     5.0
#
#     Reinforcement Learning: Posty - Elastyczne  \
# 0                                          2.0
# 1                                          5.0
# 2                                          5.0
# 3                                          2.0
# 4                                          3.0
# 5                                          5.0
# 6                                          4.0
# 7                                          2.0
# 8                                          3.0
# 9                                          4.0
# 10                                         1.0
# 11                                         5.0
# 12                                         4.0
# 13                                         1.0
# 14                                         4.0
# 15                                         2.0
# 16                                         5.0
# 17                                         4.0
# 18                                         2.0
# 19                                         4.0
# 20                                         2.0
# 21                                         4.0
#
#     Reinforcement Learning: Posty - Ugruntowane  \
# 0                                           2.0
# 1                                           5.0
# 2                                           4.0
# 3                                           2.0
# 4                                           2.0
# 5                                           3.0
# 6                                           3.0
# 7                                           2.0
# 8                                           3.0
# 9                                           3.0
# 10                                          1.0
# 11                                          5.0
# 12                                          4.0
# 13                                          1.0
# 14                                          4.0
# 15                                          3.0
# 16                                          5.0
# 17                                          3.0
# 18                                          2.0
# 19                                          4.0
# 20                                          4.0
# 21                                          4.0
#
#     Reinforcement Learning: Posty - Rozszerzalne  \
# 0                                            3.0
# 1                                            3.0
# 2                                            2.0
# 3                                            2.0
# 4                                            2.0
# 5                                            3.0
# 6                                            2.0
# 7                                            3.0
# 8                                            3.0
# 9                                            4.0
# 10                                           1.0
# 11                                           5.0
# 12                                           4.0
# 13                                           3.0
# 14                                           4.0
# 15                                           2.0
# 16                                           5.0
# 17                                           5.0
# 18                                           3.0
# 19                                           4.0
# 20                                           4.0
# 21                                           4.0
#
#     Reinforcement Learning: Posty - Oparte na źródłach  IT_ED  IT_WORK
# 0                                                 3.0       0        0
# 1                                                 5.0       1        1
# 2                                                 4.0       1        1
# 3                                                 4.0       1        1
# 4                                                 2.0       1        1
# 5                                                 3.0       0        0
# 6                                                 3.0       0        0
# 7                                                 2.0       0        0
# 8                                                 3.0       0        1
# 9                                                 3.0       1        1
# 10                                                1.0       1        1
# 11                                                5.0       0        0
# 12                                                4.0       1        1
# 13                                                1.0       1        1
# 14                                                4.0       0        0
# 15                                                3.0       1        1
# 16                                                5.0       1        1
# 17                                                2.0       1        1
# 18                                                2.0       1        1
# 19                                                4.0       1        1
# 20                                                4.0       1        1
# 21                                                2.0       1        1
#
# [22 rows x 62 columns]

# %%
prefixes = ['Content-based Filtering', 'Collaborative Filtering BPR', 'Reinforcement Learning']
rating_cols = [col for col in df.columns if any(col.startswith(prefix) for prefix in prefixes)]
rating_cols
# Out:
# ['Content-based Filtering: Filmy - Satysfakcja',
#  'Content-based Filtering: Filmy - Proste',
#  'Content-based Filtering: Filmy - Elastyczne',
#  'Content-based Filtering: Filmy - Ugruntowane',
#  'Content-based Filtering: Filmy - Rozszerzalne',
#  'Content-based Filtering: Filmy - Oparte na źródłach',
#  'Collaborative Filtering BPR: Filmy - Satysfakcja',
#  'Collaborative Filtering BPR: Filmy - Proste',
#  'Collaborative Filtering BPR: Filmy - Elastyczne',
#  'Collaborative Filtering BPR: Filmy - Ugruntowane',
#  'Collaborative Filtering BPR: Filmy - Rozszerzalne',
#  'Collaborative Filtering BPR: Filmy - Oparte na źródłach',
#  'Reinforcement Learning: Filmy - Satysfakcja',
#  'Reinforcement Learning: Filmy - Proste',
#  'Reinforcement Learning: Filmy - Elastyczne',
#  'Reinforcement Learning: Filmy - Ugruntowane',
#  'Reinforcement Learning: Filmy - Rozszerzalne',
#  'Reinforcement Learning: Filmy - Oparte na źródłach',
#  'Content-based Filtering: Oferty kupna produktów - Satysfakcja',
#  'Content-based Filtering: Oferty kupna produktów - Proste',
#  'Content-based Filtering: Oferty kupna produktów - Elastyczne',
#  'Content-based Filtering: Oferty kupna produktów - Ugruntowane',
#  'Content-based Filtering: Oferty kupna produktów - Rozszerzalne',
#  'Content-based Filtering: Oferty kupna produktów - Oparte na źródłach',
#  'Collaborative Filtering BPR: Oferty kupna produktów - Satysfakcja',
#  'Collaborative Filtering BPR: Oferty kupna produktów - Proste',
#  'Collaborative Filtering BPR: Oferty kupna produktów - Elastyczne',
#  'Collaborative Filtering BPR: Oferty kupna produktów - Ugruntowane',
#  'Collaborative Filtering BPR: Oferty kupna produktów - Rozszerzalne',
#  'Collaborative Filtering BPR: Oferty kupna produktów - Oparte na źródłach',
#  'Reinforcement Learning: Oferty kupna produktów - Satysfakcja',
#  'Reinforcement Learning: Oferty kupna produktów - Proste',
#  'Reinforcement Learning: Oferty kupna produktów - Elastyczne',
#  'Reinforcement Learning: Oferty kupna produktów - Ugruntowane',
#  'Reinforcement Learning: Oferty kupna produktów - Rozszerzalne',
#  'Reinforcement Learning: Oferty kupna produktów - Oparte na źródłach',
#  'Content-based Filtering: Posty - Satysfakcja',
#  'Content-based Filtering: Posty - Proste',
#  'Content-based Filtering: Posty - Elastyczne',
#  'Content-based Filtering: Posty - Ugruntowane',
#  'Content-based Filtering: Posty - Rozszerzalne',
#  'Content-based Filtering: Posty - Oparte na źródłach',
#  'Collaborative Filtering BPR: Posty - Satysfakcja',
#  'Collaborative Filtering BPR: Posty - Proste',
#  'Collaborative Filtering BPR: Posty - Elastyczne',
#  'Collaborative Filtering BPR: Posty - Ugruntowane',
#  'Collaborative Filtering BPR: Posty - Rozszerzalne',
#  'Collaborative Filtering BPR: Posty - Oparte na źródłach',
#  'Reinforcement Learning: Posty - Satysfakcja',
#  'Reinforcement Learning: Posty - Proste',
#  'Reinforcement Learning: Posty - Elastyczne',
#  'Reinforcement Learning: Posty - Ugruntowane',
#  'Reinforcement Learning: Posty - Rozszerzalne',
#  'Reinforcement Learning: Posty - Oparte na źródłach']

# %%
grouped_df = df.groupby(['IT_ED', 'IT_WORK'])[rating_cols].mean()
grouped_df
# Out:
#                Content-based Filtering: Filmy - Satysfakcja  \
# IT_ED IT_WORK
# 0     0                                            3.333333
#       1                                            2.000000
# 1     1                                            3.800000
#
#                Content-based Filtering: Filmy - Proste  \
# IT_ED IT_WORK
# 0     0                                       3.833333
#       1                                       3.000000
# 1     1                                       4.333333
#
#                Content-based Filtering: Filmy - Elastyczne  \
# IT_ED IT_WORK
# 0     0                                           3.833333
#       1                                           3.000000
# 1     1                                           3.866667
#
#                Content-based Filtering: Filmy - Ugruntowane  \
# IT_ED IT_WORK
# 0     0                                            3.666667
#       1                                            2.000000
# 1     1                                            3.533333
#
#                Content-based Filtering: Filmy - Rozszerzalne  \
# IT_ED IT_WORK
# 0     0                                             3.666667
#       1                                             2.000000
# 1     1                                             3.533333
#
#                Content-based Filtering: Filmy - Oparte na źródłach  \
# IT_ED IT_WORK
# 0     0                                                 3.166667
#       1                                                 2.000000
# 1     1                                                 3.000000
#
#                Collaborative Filtering BPR: Filmy - Satysfakcja  \
# IT_ED IT_WORK
# 0     0                                                3.666667
#       1                                                4.000000
# 1     1                                                3.733333
#
#                Collaborative Filtering BPR: Filmy - Proste  \
# IT_ED IT_WORK
# 0     0                                           4.000000
#       1                                           4.000000
# 1     1                                           4.266667
#
#                Collaborative Filtering BPR: Filmy - Elastyczne  \
# IT_ED IT_WORK
# 0     0                                                    4.0
#       1                                                    3.0
# 1     1                                                    3.6
#
#                Collaborative Filtering BPR: Filmy - Ugruntowane  ...  \
# IT_ED IT_WORK                                                    ...
# 0     0                                                3.666667  ...
#       1                                                2.000000  ...
# 1     1                                                3.600000  ...
#
#                Collaborative Filtering BPR: Posty - Elastyczne  \
# IT_ED IT_WORK
# 0     0                                               3.500000
#       1                                               3.000000
# 1     1                                               3.733333
#
#                Collaborative Filtering BPR: Posty - Ugruntowane  \
# IT_ED IT_WORK
# 0     0                                                4.166667
#       1                                                3.000000
# 1     1                                                3.333333
#
#                Collaborative Filtering BPR: Posty - Rozszerzalne  \
# IT_ED IT_WORK
# 0     0                                                      3.5
#       1                                                      5.0
# 1     1                                                      3.8
#
#                Collaborative Filtering BPR: Posty - Oparte na źródłach  \
# IT_ED IT_WORK
# 0     0                                                 4.000000
#       1                                                 3.000000
# 1     1                                                 3.333333
#
#                Reinforcement Learning: Posty - Satysfakcja  \
# IT_ED IT_WORK
# 0     0                                           3.666667
#       1                                           2.000000
# 1     1                                           3.533333
#
#                Reinforcement Learning: Posty - Proste  \
# IT_ED IT_WORK
# 0     0                                      3.833333
#       1                                      3.000000
# 1     1                                      3.533333
#
#                Reinforcement Learning: Posty - Elastyczne  \
# IT_ED IT_WORK
# 0     0                                          3.666667
#       1                                          3.000000
# 1     1                                          3.200000
#
#                Reinforcement Learning: Posty - Ugruntowane  \
# IT_ED IT_WORK
# 0     0                                           3.166667
#       1                                           3.000000
# 1     1                                           3.133333
#
#                Reinforcement Learning: Posty - Rozszerzalne  \
# IT_ED IT_WORK
# 0     0                                            3.333333
#       1                                            3.000000
# 1     1                                            3.200000
#
#                Reinforcement Learning: Posty - Oparte na źródłach
# IT_ED IT_WORK
# 0     0                                                 3.333333
#       1                                                 3.000000
# 1     1                                                 3.066667
#
# [3 rows x 54 columns]

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# split_columns = grouped_df.columns.str.extract(r'(?P<Algorithm>.*?): (?P<Dataset>.*?) - (?P<Metric>.*)')
# split_columns.index = grouped_df.columns

# # Funkcja do rysowania histogramów dla pojedynczej grupy
# def plot_group_histograms(group, group_name):
#     # Zamień kolumny na MultiIndex (Algorithm, Dataset, Metric)
#     group.columns = pd.MultiIndex.from_frame(split_columns.loc[group.columns])
    
#     # Iteruj po datasetach
#     for dataset in group.columns.levels[1]:
#         dataset_data = group.xs(dataset, level='Dataset', axis=1)
#         if dataset_data.empty:
#             continue
#         # Iteruj po metrykach
#         for metric in dataset_data.columns.levels[1]:
#             metric_data = dataset_data.xs(metric, level='Metric', axis=1)
#             if metric_data.empty:
#                 continue
#             # Rysuj histogramy dla algorytmów
#             metric_data.plot(kind='bar', title=f'Group: {group_name} | Dataset: {dataset} | Metric: {metric}')
#             plt.xlabel('Group (IT_ED, IT_WORK)')
#             plt.ylabel(metric)
#             plt.legend(title='Algorithm', loc='upper right')
#             plt.tight_layout()
#             plt.show()

# # Iteruj po grupach (index to MultiIndex (IT_ED, IT_WORK))
# for idx, row in grouped_df.iterrows():
#     # row to Series – musimy przekonwertować na DataFrame z jednym wierszem
#     row_df = pd.DataFrame(row).T
#     plot_group_histograms(row_df, group_name=idx)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np

# df['group'] = np.where((df['IT_ED'] == 0) & (df['IT_WORK'] == 0), 'no IT experience', 'IT experience')
# grouped = df.groupby('group')[rating_cols].mean()

# # Średnia dla całego df (wszystkich danych)
# overall = df[rating_cols].mean().to_frame().T
# overall.index = ['all']  # nadajemy indeks 'all'

# # Łączymy oba wyniki w jeden DataFrame
# grouped_df = pd.concat([grouped, overall])


# split_columns = grouped_df.columns.str.extract(r'(?P<Algorithm>.*?): (?P<Dataset>.*?) - (?P<Metric>.*)')
# split_columns.index = grouped_df.columns

# # Funkcja do rysowania histogramów dla pojedynczej grupy
# def plot_group_histograms(group):
#     # Zamień kolumny na MultiIndex (Algorithm, Dataset, Metric)
#     group.columns = pd.MultiIndex.from_frame(split_columns.loc[group.columns])
    
#     # Iteruj po datasetach
#     for dataset in group.columns.levels[1]:
#         dataset_data = group.xs(dataset, level='Dataset', axis=1)
#         if dataset_data.empty:
#             continue
#         # Iteruj po metrykach
#         for metric in dataset_data.columns.levels[1]:
#             metric_data = dataset_data.xs(metric, level='Metric', axis=1)
#             if metric_data.empty:
#                 continue
#             # Rysuj histogramy dla algorytmów
#             metric_data.plot(kind='bar', title=f'Dataset: {dataset} | Metric: {metric}')
#             plt.ylabel(metric)
#             plt.legend(title='Algorithm', loc='upper right')
#             plt.tight_layout()
#             plt.show()


# plot_group_histograms(grouped_df)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np

# # Przykład: rating_cols to lista kolumn z ocenami
# # rating_cols = [...]

# df['group'] = np.where((df['IT_ED'] == 0) & (df['IT_WORK'] == 0), 'no IT experience', 'IT experience')
# grouped = df.groupby('group')[rating_cols].mean()

# # Średnia dla całego df (wszystkich danych)
# overall = df[rating_cols].mean().to_frame().T
# overall.index = ['all']  # nadajemy indeks 'all'

# # Łączymy oba wyniki w jeden DataFrame
# grouped_df = pd.concat([grouped, overall])

# # Rozbijamy nazwy kolumn na MultiIndex
# split_columns = grouped_df.columns.str.extract(r'(?P<Algorithm>.*?): (?P<Dataset>.*?) - (?P<Metric>.*)')
# split_columns.index = grouped_df.columns

# # Mapowanie pełnych nazw na skróty
# algorithm_map = {
#     'Collaborative Filtering BPR': 'CF',
#     'Content-based Filtering': 'CBF',
#     'Reinforcement Learning': 'RL'
# }

# # Zamiana nazw algorytmów na skróty
# split_columns['Algorithm'] = split_columns['Algorithm'].replace(algorithm_map)

# # Ustaw MultiIndex kolumn
# grouped_df.columns = pd.MultiIndex.from_frame(split_columns)

# # Funkcja do rysowania histogramów dla pojedynczej grupy
# def plot_group_histograms(group):
#     # Iteruj po datasetach
#     for dataset in group.columns.levels[1]:
#         dataset_data = group.xs(dataset, level='Dataset', axis=1)
#         if dataset_data.empty:
#             continue
#         # Iteruj po metrykach
#         for metric in dataset_data.columns.levels[1]:
#             metric_data = dataset_data.xs(metric, level='Metric', axis=1)
#             if metric_data.empty:
#                 continue
#             # Rysuj histogramy dla algorytmów
#             metric_data.plot(kind='bar', title=f'Dataset: {dataset} | Metric: {metric}')
#             plt.ylabel(metric)
#             plt.legend(title='Algorithm', loc='upper right')
#             plt.tight_layout()
#             plt.show()

# plot_group_histograms(grouped_df)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np

# # Grupa i średnie
# df['group'] = np.where((df['IT_ED'] == 0) & (df['IT_WORK'] == 0), 'no IT experience', 'IT experience')
# grouped = df.groupby('group')[rating_cols].mean()
# overall = df[rating_cols].mean().to_frame().T
# overall.index = ['all']
# grouped_df = pd.concat([grouped, overall])

# # Rozbij kolumny
# split_columns = grouped_df.columns.str.extract(r'(?P<Algorithm>.*?): (?P<Dataset>.*?) - (?P<Metric>.*)')
# split_columns.index = grouped_df.columns

# algorithm_map = {
#     'Collaborative Filtering BPR': 'CF',
#     'Content-based Filtering': 'CBF',
#     'Reinforcement Learning': 'RL'
# }
# split_columns['Algorithm'] = split_columns['Algorithm'].replace(algorithm_map)
# grouped_df.columns = pd.MultiIndex.from_frame(split_columns)

# def plot_group_histograms_one_fig_per_dataset(group):
#     for dataset in group.columns.levels[1]:
#         dataset_data = group.xs(dataset, level='Dataset', axis=1)
#         if dataset_data.empty:
#             continue

#         metrics = dataset_data.columns.levels[1]
#         n_metrics = len(metrics)

#         n_cols = 3
#         n_rows = (n_metrics + n_cols - 1) // n_cols

#         fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 5, n_rows * 5), squeeze=False)

#         for idx, metric in enumerate(metrics):
#             row = idx // n_cols
#             col = idx % n_cols
#             ax = axes[row, col]

#             metric_data = dataset_data.xs(metric, level='Metric', axis=1)
#             if metric_data.empty:
#                 ax.axis('off')
#                 continue

#             alg_labels = metric_data.columns.get_level_values('Algorithm')
#             width = 0.8 / len(metric_data.columns)
#             x = np.arange(len(metric_data.index))

#             for i, col_name in enumerate(metric_data.columns):
#                 alg = alg_labels[i]
#                 heights = metric_data.iloc[:, i]
#                 bar_positions = x - 0.4 + i * width + width / 2
#                 bars = ax.bar(bar_positions, heights, width=width, label=alg)

#                 for j, bar in enumerate(bars):
#                     ax.text(
#                         bar.get_x() + bar.get_width() / 2,
#                         bar.get_height() + 0.01,
#                         alg,
#                         ha='center', va='bottom', fontsize=10
#                     )

#             ax.set_xticks(x)
#             ax.set_xticklabels(metric_data.index)
#             ax.set_ylim(0, 5)
#             ax.set_title(metric)

#         # Ukryj puste wykresy w siatce
#         for idx in range(n_metrics, n_rows * n_cols):
#             row = idx // n_cols
#             col = idx % n_cols
#             axes[row, col].axis('off')

#         plt.tight_layout(rect=[0, 0, 1, 0.95])
#         plt.show()


# # Uruchom
# plot_group_histograms_one_fig_per_dataset(grouped_df)

# %%
import seaborn as sns

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Grupa i średnie
df['group'] = np.where((df['IT_ED'] == 0) & (df['IT_WORK'] == 0), 'no IT experience', 'IT experience')
grouped = df.groupby('group')[rating_cols].mean()
overall = df[rating_cols].mean().to_frame().T
overall.index = ['all']
grouped_df = pd.concat([grouped, overall])

# Rozbij kolumny
split_columns = grouped_df.columns.str.extract(r'(?P<Algorithm>.*?): (?P<Dataset>.*?) - (?P<Metric>.*)')
split_columns.index = grouped_df.columns

algorithm_map = {
    'Collaborative Filtering BPR': 'CF',
    'Content-based Filtering': 'CBF',
    'Reinforcement Learning': 'RL'
}
split_columns['Algorithm'] = split_columns['Algorithm'].replace(algorithm_map)
grouped_df.columns = pd.MultiIndex.from_frame(split_columns)

def plot_group_histograms_one_fig_per_dataset(group):
    metric_map = {
        'Satysfakcja': 'Satisfaction',
        'Proste': 'Simple',
        'Elastyczne': 'Flexible',
        'Ugruntowane': 'Grounded',
        'Rozszerzalne': 'Extendable',
        'Oparte na źródłach': 'Source-based'
    }
    dataset_map = {
        'Oferty kupna produktów': 'amazonsales',
        'Filmy': 'movielens',
        'Posty': 'postrec'
    }
    ordered_metrics_pl = [
        'Satysfakcja',
        'Proste',
        'Elastyczne',
        'Ugruntowane',
        'Rozszerzalne',
        'Oparte na źródłach'
    ]

    # Używamy palety Set2 z seaborn
    palette = sns.color_palette('Set2')

    for dataset in group.columns.levels[1]:
        dataset_data = group.xs(dataset, level='Dataset', axis=1)
        if dataset_data.empty:
            continue

        metrics = ordered_metrics_pl
        n_metrics = len(metrics)
        n_cols = 3
        n_rows = (n_metrics + n_cols - 1) // n_cols

        fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 4, n_rows * 4), squeeze=False)

        for idx, metric_pl in enumerate(metrics):
            row = idx // n_cols
            col = idx % n_cols
            ax = axes[row, col]

            try:
                metric_data = dataset_data.xs(metric_pl, level='Metric', axis=1)
            except KeyError:
                ax.axis('off')
                continue

            if metric_data.empty:
                ax.axis('off')
                continue

            alg_labels = metric_data.columns.get_level_values('Algorithm')
            width = 0.8 / len(metric_data.columns)
            x = np.arange(len(metric_data.index))

            for i, col_name in enumerate(metric_data.columns):
                alg = alg_labels[i]
                heights = metric_data.iloc[:, i]
                bar_positions = x - 0.4 + i * width + width / 2
                bars = ax.bar(bar_positions, heights, width=width, label=alg, color=palette[i % len(palette)])

                for j, bar in enumerate(bars):
                    ax.text(
                        bar.get_x() + bar.get_width() / 2,
                        bar.get_height() + 0.01,
                        alg,
                        ha='center', va='bottom', fontsize=10, color='black'
                    )

            ax.set_xticks(x)
            ax.set_xticklabels(metric_data.index)
            ax.set_ylim(0, 5)
            ax.yaxis.grid(True, linestyle='--', linewidth=0.7, alpha=0.7)

            metric_en = metric_map.get(metric_pl, metric_pl)
            ax.set_title(metric_en)

        for idx in range(n_metrics, n_rows * n_cols):
            row = idx // n_cols
            col = idx % n_cols
            axes[row, col].axis('off')

        dataset_en = dataset_map.get(dataset, dataset)
        plt.tight_layout(rect=[0, 0, 1, 0.95])
        plt.savefig(f'fig/{dataset_en}.png')
        plt.show()


plot_group_histograms_one_fig_per_dataset(grouped_df)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Grupa i średnie
df['group'] = np.where((df['IT_ED'] == 0) & (df['IT_WORK'] == 0), 'no IT experience', 'IT experience')
grouped = df.groupby('group')[rating_cols].mean()
overall = df[rating_cols].mean().to_frame().T
overall.index = ['all']
grouped_df = pd.concat([grouped, overall])

# Rozbij kolumny
split_columns = grouped_df.columns.str.extract(r'(?P<Algorithm>.*?): (?P<Dataset>.*?) - (?P<Metric>.*)')
split_columns.index = grouped_df.columns

algorithm_map = {
    'Collaborative Filtering BPR': 'CF',
    'Content-based Filtering': 'CBF',
    'Reinforcement Learning': 'RL'
}
split_columns['Algorithm'] = split_columns['Algorithm'].replace(algorithm_map)
grouped_df.columns = pd.MultiIndex.from_frame(split_columns)

# 📌 1) Uśrednianie po datasetach dla każdego algorytmu i metryki
# Teraz dane mają index (group), a kolumny 3-poziomowe (Algorithm, Dataset, Metric)
# Chcemy uśrednić po poziomie 'Dataset'
grouped_avg = grouped_df.groupby(level=['Algorithm', 'Metric'], axis=1).mean()

def plot_histograms_by_algorithm(group_avg):
    metric_map = {
        'Satysfakcja': 'Satisfaction',
        'Proste': 'Simple',
        'Elastyczne': 'Flexible',
        'Ugruntowane': 'Grounded',
        'Rozszerzalne': 'Extendable',
        'Oparte na źródłach': 'Source-based'
    }
    ordered_metrics_pl = [
        'Satysfakcja',
        'Proste',
        'Elastyczne',
        'Ugruntowane',
        'Rozszerzalne',
        'Oparte na źródłach'
    ]

    palette = sns.color_palette('Set2')

    n_metrics = len(ordered_metrics_pl)
    n_cols = 3
    n_rows = (n_metrics + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 4, n_rows * 4), squeeze=False)

    for idx, metric_pl in enumerate(ordered_metrics_pl):
        row = idx // n_cols
        col = idx % n_cols
        ax = axes[row, col]

        # Pobierz kolumny tylko dla tej metryki
        metric_data = group_avg.xs(metric_pl, level='Metric', axis=1)

        if metric_data.empty:
            ax.axis('off')
            continue

        alg_labels = metric_data.columns
        width = 0.8 / len(alg_labels)
        x = np.arange(len(metric_data.index))

        for i, alg in enumerate(alg_labels):
            heights = metric_data.iloc[:, i]
            bar_positions = x - 0.4 + i * width + width / 2
            bars = ax.bar(bar_positions, heights, width=width, label=alg, color=palette[i % len(palette)])

            for j, bar in enumerate(bars):
                ax.text(
                    bar.get_x() + bar.get_width() / 2,
                    bar.get_height() + 0.01,
                    alg,
                    ha='center', va='bottom', fontsize=10, color='black'
                )

        ax.set_xticks(x)
        ax.set_xticklabels(metric_data.index)
        ax.set_ylim(0, 5)
        ax.yaxis.grid(True, linestyle='--', linewidth=0.7, alpha=0.7)

        metric_en = metric_map.get(metric_pl, metric_pl)
        ax.set_title(metric_en)

    for idx in range(n_metrics, n_rows * n_cols):
        row = idx // n_cols
        col = idx % n_cols
        axes[row, col].axis('off')

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(f'fig/all.png')
    plt.show()

plot_histograms_by_algorithm(grouped_avg)
# Out:
# C:\Users\julia\AppData\Local\Temp\ipykernel_18324\1471018930.py:28: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   grouped_avg = grouped_df.groupby(level=['Algorithm', 'Metric'], axis=1).mean()
